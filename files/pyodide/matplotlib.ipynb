# %% [markdown]
# ## Matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 5, 555)
plt.plot(x, np.sin(x));

# %%
plt.show()

# %% [markdown]
# ## Matplotlib: support for widgets backend

# %%
# %pip install -q ipympl

# %%
# %matplotlib widget
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 get_ipython().run_line_magic('matplotlib', 'widget')
#
# File /lib/python3.13/site-packages/IPython/core/interactiveshell.py:2481, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2479     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2480 with self.builtin_trap:
# -> 2481     result = fn(*args, **kwargs)
#    2483 # The code below prevents the output from being displayed
#    2484 # when using magics with decorator @output_can_be_silenced
#    2485 # when the last Python token in the expression is a ';'.
#    2486 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File /lib/python3.13/site-packages/IPython/core/magics/pylab.py:103, in PylabMagics.matplotlib(self, line)
#      98     print(
#      99         "Available matplotlib backends: %s"
# ...

# %%
x = np.linspace(0, 10, 1000)
plt.plot(x, np.sin(x))
